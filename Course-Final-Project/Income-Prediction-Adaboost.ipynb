# %%
# %run C:/Users/u1448398/Income_Prediction_1.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25000 non-null  int64
#  1   workclass       25000 non-null  object
#  2   fnlwgt          25000 non-null  int64
#  3   education       25000 non-null  object
#  4   education.num   25000 non-null  int64
#  5   marital.status  25000 non-null  object
#  6   occupation      25000 non-null  object
#  7   relationship    25000 non-null  object
#  8   race            25000 non-null  object
#  9   sex             25000 non-null  object
#  10  capital.gain    25000 non-null  int64
#  11  capital.loss    25000 non-null  int64
#  12  hours.per.week  25000 non-null  int64
#  13  native.country  25000 non-null  object
#  14  income>50K      25000 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 2.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score
import csv

# Load data
X_train = df.drop('income>50K', axis=1)
y_train = df['income>50K']
X_test = df_test.copy()

# Train an AdaBoostClassifier
adaboost_classifier = AdaBoostClassifier(n_estimators=50, random_state=42)
adaboost_classifier.fit(X_train, y_train)

# Identify missing categorical features in the test data and fill them with zeros
missing_categorical_columns = set(categorical_columns) - set(X_train.columns)
for col in missing_categorical_columns:
    X_test[col] = 0

# Generate predictions on the test data
expected_columns = list(X_train.columns)
X_test = df_test[expected_columns]
predictions = adaboost_classifier.predict_proba(X_test)[:, 1]  # Probability predictions

# Generate an array of IDs for the test data
test_ids = range(1, len(df_test) + 1)

# Create a DataFrame for the predictions
predictions_df = pd.DataFrame({'ID': test_ids, 'Prediction': predictions})

# Save the predictions in the desired format
predictions_df.to_csv("Predictions-with-adaboost.csv", index=False)
