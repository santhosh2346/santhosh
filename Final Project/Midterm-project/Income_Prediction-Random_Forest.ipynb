# %%
# %run C:/Users/u1464674/Income_Prediction_1.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25000 non-null  int64
#  1   workclass       25000 non-null  object
#  2   fnlwgt          25000 non-null  int64
#  3   education       25000 non-null  object
#  4   education.num   25000 non-null  int64
#  5   marital.status  25000 non-null  object
#  6   occupation      25000 non-null  object
#  7   relationship    25000 non-null  object
#  8   race            25000 non-null  object
#  9   sex             25000 non-null  object
#  10  capital.gain    25000 non-null  int64
#  11  capital.loss    25000 non-null  int64
#  12  hours.per.week  25000 non-null  int64
#  13  native.country  25000 non-null  object
#  14  income>50K      25000 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 2.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import roc_auc_score
import csv


# Load data
#train_df = pd.read_csv("C:\\Rushiil\\ML\\train_final.csv")
X_train = df.drop('income>50K',axis=1)
y_train = df['income>50K']

X_test = df_test.copy()

random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Identifying missing categorical features in the test data
missing_categorical_columns = set(categorical_columns) - set(X_train.columns)


for col in missing_categorical_columns:
    test_data[col] = 0


# Generate predictions on the test data
X_test = df_test  
# Ensuring that the test data includes all the columns that the model was trained on
expected_columns = list(X_train.columns)
X_test = df_test[expected_columns]
predictions = random_forest.predict_proba(X_test)  # Probability predictions

# Assuming that predictions[:, 1] represents the probability of "income > 50K"

# An array of IDs for the test data
test_ids = range(1, len(df_test) + 1)

# Create a DataFrame for the predictions
predictions_df = pd.DataFrame({'ID': test_ids, 'Prediction': predictions[:, 1]})

# Saving the predictions in the desired format
predictions_df.to_csv("Predictions_using_random_forest.csv", index=False)
